# %%
# ============================================================
# CELLULE 1 : Importation des bibliothèques
# ============================================================

import pandas as pd          # Pour manipuler les données (tableaux)
import numpy as np           # Pour les calculs mathématiques
import matplotlib.pyplot as plt  # Pour faire des graphiques
import seaborn as sns        # Pour des graphiques plus jolis
import warnings
warnings.filterwarnings('ignore')  # Cacher les messages d'avertissement

print("✅ Bibliothèques importées avec succès !")
# Out:
# ✅ Bibliothèques importées avec succès !

# %%
# ============================================================
# CELLULE 2 : Chargement des données
# ============================================================

# On charge le fichier CSV depuis le dossier data/raw/
df = pd.read_csv('../data/raw/data_original.csv')

# Afficher les dimensions du tableau
print(f"📊 Le dataset contient : {df.shape[0]} lignes et {df.shape[1]} colonnes")
print(f"📋 Nom des colonnes :\n{list(df.columns)}")
# Out:
# 📊 Le dataset contient : 4372 lignes et 52 colonnes
# 📋 Nom des colonnes :
# ['CustomerID', 'Recency', 'Frequency', 'MonetaryTotal', 'MonetaryAvg', 'MonetaryStd', 'MonetaryMin', 'MonetaryMax', 'TotalQuantity', 'AvgQuantityPerTransaction', 'MinQuantity', 'MaxQuantity', 'CustomerTenureDays', 'FirstPurchaseDaysAgo', 'PreferredDayOfWeek', 'PreferredHour', 'PreferredMonth', 'WeekendPurchaseRatio', 'AvgDaysBetweenPurchases', 'UniqueProducts', 'UniqueDescriptions', 'AvgProductsPerTransaction', 'UniqueCountries', 'NegativeQuantityCount', 'ZeroPriceCount', 'CancelledTransactions', 'ReturnRatio', 'TotalTransactions', 'UniqueInvoices', 'AvgLinesPerInvoice', 'Age', 'RegistrationDate', 'NewsletterSubscribed', 'LastLoginIP', 'SupportTicketsCount', 'SatisfactionScore', 'RFMSegment', 'AgeCategory', 'SpendingCategory', 'CustomerType', 'FavoriteSeason', 'PreferredTimeOfDay', 'Region', 'LoyaltyLevel', 'ChurnRiskCategory', 'WeekendPreference', 'BasketSizeCategory', 'ProductDiversity', 'Gender', 'AccountStatus', 'Country', 'Churn']

# %%
# ============================================================
# CELLULE 3 : Premier aperçu
# ============================================================

print("=== 5 premières lignes ===")
display(df.head())

print("\n=== 5 dernières lignes ===")
display(df.tail())

print("\n=== Aperçu aléatoire de 5 lignes ===")
display(df.sample(5, random_state=42))
# Out:
# === 5 premières lignes ===
#    CustomerID  Recency  Frequency  MonetaryTotal  MonetaryAvg  MonetaryStd  \
# 0       17850      302         35        5288.63    16.950737    13.603662
# 1       13047       32         18        3079.10    15.709694    11.684769
# 2       12583        3         18        7187.34    28.634821    23.150132
# 3       13748       96          5         948.25    33.866071    42.953119
# 4       15100      330          6         635.10   105.850000   215.986263
#
#    MonetaryMin  MonetaryMax  TotalQuantity  AvgQuantityPerTransaction  ...  \
# 0       -30.60       107.25           1693                   5.426282  ...
# 1       -15.00        68.00           1355                   6.913265  ...
# 2       -60.84       132.80           5009                  19.956175  ...
# 3         9.36       204.00            439                  15.678571  ...
# 4      -131.40       350.40             58                   9.666667  ...
#
#                 Region  LoyaltyLevel  ChurnRiskCategory  WeekendPreference  \
# 0                   UK         Jeune           Critique            Inconnu
# 1                   UK        Établi              Moyen            Semaine
# 2  Europe continentale        Ancien             Faible            Semaine
# 3                   UK        Établi           Critique            Inconnu
# 4                   UK         Jeune           Critique            Inconnu
#
#    BasketSizeCategory  ProductDiversity   Gender  AccountStatus  \
# 0               Moyen       Explorateur  Unknown         Active
# 1               Moyen       Explorateur        M         Active
# 2               Grand       Explorateur  Unknown         Active
# 3               Grand       Explorateur  Unknown         Active
# 4               Moyen        Spécialisé        M         Active
#
#           Country  Churn
# 0  United Kingdom      1
# 1  United Kingdom      0
# 2          France      0
# 3  United Kingdom      1
# 4  United Kingdom      1
#
# [5 rows x 52 columns]
# === 5 dernières lignes ===
#       CustomerID  Recency  Frequency  MonetaryTotal  MonetaryAvg  MonetaryStd  \
# 4367       13436        2          1         196.89    16.407500     4.698021
# 4368       15520        2          1         343.50    19.083333     7.451560
# 4369       13298        1          1         360.00   180.000000   127.279221
# 4370       14569        1          1         227.39    18.949167    35.731358
# 4371       12713        1          1         848.55    22.330263    14.375260
#
#       MonetaryMin  MonetaryMax  TotalQuantity  AvgQuantityPerTransaction  ...  \
# 4367        10.20        25.50             76                   6.333333  ...
# 4368         9.48        34.68            314                  17.444444  ...
# 4369        90.00       270.00             96                  48.000000  ...
# 4370         1.65       122.40             79                   6.583333  ...
# 4371         5.04        71.70            508                  13.368421  ...
#
#                    Region  LoyaltyLevel  ChurnRiskCategory  WeekendPreference  \
# 4367                   UK       Nouveau             Faible            Inconnu
# 4368                   UK       Nouveau             Faible            Inconnu
# 4369                   UK       Nouveau             Faible            Inconnu
# 4370                   UK       Nouveau             Faible            Inconnu
# 4371  Europe continentale       Nouveau             Faible            Inconnu
#
#       BasketSizeCategory  ProductDiversity  Gender  AccountStatus  \
# 4367               Moyen            Modéré       M         Active
# 4368               Grand            Modéré       M         Active
# 4369               Grand        Spécialisé       F         Closed
# 4370               Moyen            Modéré       F         Active
# 4371               Moyen       Explorateur       F         Active
#
#              Country  Churn
# 4367  United Kingdom      0
# 4368  United Kingdom      0
# 4369  United Kingdom      0
# 4370  United Kingdom      0
# 4371         Germany      0
#
# [5 rows x 52 columns]
# === Aperçu aléatoire de 5 lignes ===
#       CustomerID  Recency  Frequency  MonetaryTotal  MonetaryAvg  MonetaryStd  \
# 2014       14633      266          1         344.90    17.245000     3.752434
# 457        13050        9         28        5684.61    13.470640     9.611339
# 478        17975       15         14        4393.61    14.793300    23.312296
# 438        12347        2          7        4310.00    23.681319    23.289902
# 3728       12420       64          1         600.39    20.703103     9.201862
#
#       MonetaryMin  MonetaryMax  TotalQuantity  AvgQuantityPerTransaction  ...  \
# 2014        10.20         27.0             96                   4.800000  ...
# 457        -19.90         79.6           3707                   8.784360  ...
# 478        -95.20         98.1           1552                   5.225589  ...
# 438          5.04        249.6           2458                  13.505495  ...
# 3728        10.08         39.8            345                  11.896552  ...
#
#               Region  LoyaltyLevel  ChurnRiskCategory  WeekendPreference  \
# 2014              UK       Nouveau           Critique            Inconnu
# 457               UK        Établi             Faible            Semaine
# 478               UK        Établi             Faible            Semaine
# 438   Europe du Nord        Ancien             Faible            Inconnu
# 3728   Europe du Sud       Nouveau              Élevé            Inconnu
#
#       BasketSizeCategory  ProductDiversity   Gender  AccountStatus  \
# 2014               Petit       Explorateur        F         Active
# 457                Moyen       Explorateur  Unknown         Active
# 478                Moyen       Explorateur        M         Active
# 438                Moyen       Explorateur  Unknown         Active
# 3728               Moyen       Explorateur        M         Active
#
#              Country  Churn
# 2014  United Kingdom      1
# 457   United Kingdom      0
# 478   United Kingdom      0
# 438          Iceland      0
# 3728          Cyprus      0
#
# [5 rows x 52 columns]

# %%
# ============================================================
# CELLULE 4 : Informations générales sur le dataset
# ============================================================

print("=== Types de données de chaque colonne ===")
df.info()

# Ce que ça vous dit :
# - Le type de chaque colonne (int, float, object)
# - Le nombre de valeurs non-nulles (donc vous voyez les manquantes)
# - La mémoire utilisée
# Out:
# === Types de données de chaque colonne ===
# <class 'pandas.DataFrame'>
# RangeIndex: 4372 entries, 0 to 4371
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 4372 non-null   int64
#  1   Recency                    4372 non-null   int64
#  2   Frequency                  4372 non-null   int64
#  3   MonetaryTotal              4372 non-null   float64
#  4   MonetaryAvg                4372 non-null   float64
#  5   MonetaryStd                4372 non-null   float64
#  6   MonetaryMin                4372 non-null   float64
#  7   MonetaryMax                4372 non-null   float64
#  8   TotalQuantity              4372 non-null   int64
#  9   AvgQuantityPerTransaction  4372 non-null   float64
#  10  MinQuantity                4372 non-null   int64
#  11  MaxQuantity                4372 non-null   int64
#  12  CustomerTenureDays         4372 non-null   int64
#  13  FirstPurchaseDaysAgo       4372 non-null   int64
#  14  PreferredDayOfWeek         4372 non-null   int64
#  15  PreferredHour              4372 non-null   int64
#  16  PreferredMonth             4372 non-null   int64
#  17  WeekendPurchaseRatio       4372 non-null   float64
#  18  AvgDaysBetweenPurchases    4293 non-null   float64
#  19  UniqueProducts             4372 non-null   int64
#  20  UniqueDescriptions         4372 non-null   int64
#  21  AvgProductsPerTransaction  4372 non-null   float64
#  22  UniqueCountries            4372 non-null   int64
#  23  NegativeQuantityCount      4372 non-null   int64
#  24  ZeroPriceCount             4372 non-null   int64
#  25  CancelledTransactions      4372 non-null   int64
#  26  ReturnRatio                4372 non-null   float64
#  27  TotalTransactions          4372 non-null   int64
#  28  UniqueInvoices             4372 non-null   int64
#  29  AvgLinesPerInvoice         4372 non-null   float64
#  30  Age                        3061 non-null   float64
#  31  RegistrationDate           4372 non-null   str
#  32  NewsletterSubscribed       4372 non-null   str
#  33  LastLoginIP                4372 non-null   str
#  34  SupportTicketsCount        4372 non-null   float64
#  35  SatisfactionScore          4372 non-null   float64
#  36  RFMSegment                 4372 non-null   str
#  37  AgeCategory                4372 non-null   str
#  38  SpendingCategory           4372 non-null   str
#  39  CustomerType               4372 non-null   str
#  40  FavoriteSeason             4372 non-null   str
#  41  PreferredTimeOfDay         4372 non-null   str
#  42  Region                     4372 non-null   str
#  43  LoyaltyLevel               4372 non-null   str
#  44  ChurnRiskCategory          4372 non-null   str
#  45  WeekendPreference          4372 non-null   str
#  46  BasketSizeCategory         4372 non-null   str
#  47  ProductDiversity           4372 non-null   str
#  48  Gender                     4372 non-null   str
#  49  AccountStatus              4372 non-null   str
#  50  Country                    4372 non-null   str
#  51  Churn                      4372 non-null   int64
# dtypes: float64(14), int64(20), str(18)
# memory usage: 1.7 MB

# %%
# ============================================================
# CELLULE 5 : Statistiques descriptives
# ============================================================

print("=== Statistiques des colonnes NUMÉRIQUES ===")
display(df.describe())

# describe() vous donne pour chaque colonne numérique :
# count   = nombre de valeurs (sans les NaN)
# mean    = moyenne
# std     = écart-type (dispersion)
# min/max = valeurs extrêmes
# 25%/50%/75% = quartiles

print("\n=== Statistiques des colonnes CATÉGORIELLES ===")
display(df.describe(include='object'))
# Out:
# === Statistiques des colonnes NUMÉRIQUES ===
#          CustomerID      Recency    Frequency  MonetaryTotal  MonetaryAvg  \
# count   4372.000000  4372.000000  4372.000000    4372.000000  4372.000000
# mean   15299.677722    92.047118     5.075480    1898.459701    28.839013
# std     1722.390705   100.765435     9.338754    8219.345141   127.323926
# min    12346.000000     1.000000     1.000000   -4287.630000 -4287.630000
# 25%    13812.750000    17.000000     1.000000     293.362500    10.985960
# 50%    15300.500000    50.000000     3.000000     648.075000    16.918616
# 75%    16778.250000   143.000000     5.000000    1611.725000    23.542941
# max    18287.000000   374.000000   248.000000  279489.020000  3861.000000
#
#          MonetaryStd    MonetaryMin    MonetaryMax  TotalQuantity  \
# count    4372.000000    4372.000000    4372.000000    4372.000000
# mean       88.672383     -86.425754     185.179522    1122.344007
# std      2689.001161    2876.398935    2881.283699    4672.790720
# min         0.000000 -168469.600000   -4287.630000    -303.000000
# 25%         6.226414     -11.500000      31.800000     153.000000
# 50%        10.349780       0.790000      52.020000     365.000000
# 75%        20.629858       6.960000     102.000000     962.250000
# max    137554.852393    3861.000000  168469.600000  196719.000000
#
#        AvgQuantityPerTransaction  ...  ZeroPriceCount  CancelledTransactions  \
# count                4372.000000  ...     4372.000000            4372.000000
# mean                   22.389288  ...        0.009149               2.036825
# std                   213.257466  ...        0.126218               7.340449
# min                  -144.000000  ...        0.000000               0.000000
# 25%                     5.475745  ...        0.000000               0.000000
# 50%                     9.494392  ...        0.000000               0.000000
# 75%                    14.008333  ...        0.000000               1.000000
# max                 12540.000000  ...        4.000000             226.000000
#
#        ReturnRatio  TotalTransactions  UniqueInvoices  AvgLinesPerInvoice  \
# count  4372.000000        4372.000000     4372.000000         4372.000000
# mean      0.032045          93.053294        5.075480           19.883969
# std       0.107003         232.471608        9.338754           18.512016
# min       0.000000           1.000000        1.000000            1.000000
# 25%       0.000000          17.000000        1.000000            8.000000
# 50%       0.000000          42.000000        3.000000           14.600000
# 75%       0.021009         102.000000        5.000000           25.212500
# max       1.000000        7983.000000      248.000000          219.000000
#
#                Age  SupportTicketsCount  SatisfactionScore        Churn
# count  3061.000000          4372.000000        4372.000000  4372.000000
# mean     49.149951            21.778591           5.328225     0.332571
# std      18.267835           139.267307          15.410883     0.471188
# min      18.000000            -1.000000          -1.000000     0.000000
# 25%      34.000000             1.000000           2.000000     0.000000
# 50%      49.000000             2.000000           3.000000     0.000000
# 75%      65.000000             3.000000           4.000000     1.000000
# max      80.000000           999.000000          99.000000     1.000000
#
# [8 rows x 34 columns]
# === Statistiques des colonnes CATÉGORIELLES ===
#        RegistrationDate NewsletterSubscribed     LastLoginIP  RFMSegment  \
# count              4372                 4372            4372        4372
# unique             1700                    1            4372           4
# top          2010-12-21                  Yes  59.252.219.201  Potentiels
# freq                 11                 4372               1        1589
#
#        AgeCategory SpendingCategory CustomerType FavoriteSeason  \
# count         4372             4372         4372           4372
# unique           7                4            5              4
# top        Inconnu             High  Occasionnel        Automne
# freq          1311             1664         1198           1768
#
#        PreferredTimeOfDay Region LoyaltyLevel ChurnRiskCategory  \
# count                4372   4372         4372              4372
# unique                  4     13            4                 4
# top                 Matin     UK      Nouveau            Faible
# freq                 1471   3959         1714              1695
#
#        WeekendPreference BasketSizeCategory ProductDiversity   Gender  \
# count               4372               4372             4372     4372
# unique                 3                  3                3        3
# top              Inconnu              Moyen      Explorateur  Unknown
# freq                3125               2414             3018     1649
#
#        AccountStatus         Country
# count           4372            4372
# unique             4              37
# top           Active  United Kingdom
# freq            3944            3950

# %%
# ============================================================
# CELLULE 6 : Valeurs manquantes (NaN)
# ============================================================

# Compter les valeurs manquantes par colonne
valeurs_manquantes = df.isnull().sum()
pourcentage = (df.isnull().sum() / len(df)) * 100

# Créer un tableau récapitulatif
resume_nan = pd.DataFrame({
    'Valeurs manquantes': valeurs_manquantes,
    'Pourcentage (%)': pourcentage.round(2)
})

# Afficher seulement les colonnes qui ont des NaN
resume_nan = resume_nan[resume_nan['Valeurs manquantes'] > 0].sort_values('Pourcentage (%)', ascending=False)

print("=== Colonnes avec des valeurs manquantes ===")
display(resume_nan)

# Visualisation graphique
plt.figure(figsize=(10, 5))
plt.bar(resume_nan.index, resume_nan['Pourcentage (%)'], color='salmon')
plt.title('Pourcentage de valeurs manquantes par colonne')
plt.xlabel('Colonnes')
plt.ylabel('Pourcentage (%)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('../reports/valeurs_manquantes.png')  # Sauvegarder le graphique
plt.show()
print("✅ Graphique sauvegardé dans reports/")
# Out:
# === Colonnes avec des valeurs manquantes ===
#                          Valeurs manquantes  Pourcentage (%)
# Age                                    1311            29.99
# AvgDaysBetweenPurchases                  79             1.81
# ✅ Graphique sauvegardé dans reports/

# %%
# ============================================================
# CELLULE 7 : Doublons
# ============================================================

nb_doublons = df.duplicated().sum()
print(f"🔍 Nombre de lignes dupliquées : {nb_doublons}")

if nb_doublons > 0:
    print("Voici un aperçu des doublons :")
    display(df[df.duplicated(keep=False)].head(10))
else:
    print("✅ Aucun doublon détecté !")
# Out:
# 🔍 Nombre de lignes dupliquées : 0
# ✅ Aucun doublon détecté !

# %%
# ============================================================
# CELLULE 8 : Valeurs aberrantes (outliers)
# ============================================================

print("=== SupportTicketsCount ===")
print(df['SupportTicketsCount'].value_counts().sort_index())

print("\n=== SatisfactionScore ===")
print(df['SatisfactionScore'].value_counts().sort_index())

# Visualisation boxplot pour voir les outliers
colonnes_numeriques = [
    'MonetaryTotal', 'Recency', 'Frequency', 
    'TotalQuantity', 'SupportTicketsCount', 
    'SatisfactionScore', 'Age'
]

fig, axes = plt.subplots(2, 4, figsize=(16, 8))
axes = axes.flatten()

for i, col in enumerate(colonnes_numeriques):
    if col in df.columns:
        axes[i].boxplot(df[col].dropna())
        axes[i].set_title(col)
        axes[i].set_ylabel('Valeurs')

plt.suptitle('Boxplots - Détection des valeurs aberrantes', fontsize=14)
plt.tight_layout()
plt.savefig('../reports/boxplots_outliers.png')
plt.show()

print("✅ Graphique sauvegardé dans reports/")
# Out:
# === SupportTicketsCount ===
# SupportTicketsCount
# -1.0        43
#  0.0       596
#  1.0      1140
#  2.0      1183
#  3.0       753
#  4.0       365
#  5.0       141
#  6.0        41
#  7.0        17
#  8.0         3
#  9.0         3
#  999.0      87
# Name: count, dtype: int64
#
# === SatisfactionScore ===
# SatisfactionScore
# -1.0     115
#  0.0     120
#  1.0     824
#  2.0     777
#  3.0     789
#  4.0     786
#  5.0     847
#  99.0    114
# Name: count, dtype: int64
# ✅ Graphique sauvegardé dans reports/

# %%
# ============================================================
# CELLULE 9 : Distribution de la variable cible CHURN
# ============================================================

# Churn = 0 signifie client fidèle, Churn = 1 = client parti
print("=== Distribution du Churn ===")
print(df['Churn'].value_counts())
print(f"\nPourcentage de clients partis : {df['Churn'].mean()*100:.2f}%")

# Graphique
plt.figure(figsize=(6, 4))
df['Churn'].value_counts().plot(kind='bar', color=['steelblue', 'salmon'])
plt.title('Distribution du Churn (0=Fidèle, 1=Parti)')
plt.xlabel('Churn')
plt.ylabel('Nombre de clients')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('../reports/distribution_churn.png')
plt.show()
# Out:
# === Distribution du Churn ===
# Churn
# 0    2918
# 1    1454
# Name: count, dtype: int64
#
# Pourcentage de clients partis : 33.26%

# %%
# ============================================================
# CELLULE 10 : Corrélation entre les features numériques
# ============================================================

# Sélectionner uniquement les colonnes numériques
df_numerique = df.select_dtypes(include=[np.number])

# Calculer la matrice de corrélation
matrice_corr = df_numerique.corr()

# Afficher sous forme de heatmap (carte de chaleur)
plt.figure(figsize=(18, 14))
sns.heatmap(
    matrice_corr,
    annot=False,       # Ne pas afficher les chiffres (trop de colonnes)
    cmap='coolwarm',   # Rouge = corrélation positive, Bleu = négative
    center=0,
    vmin=-1, vmax=1
)
plt.title('Matrice de corrélation des features numériques', fontsize=14)
plt.tight_layout()
plt.savefig('../reports/matrice_correlation.png')
plt.show()

# Trouver les paires très corrélées (> 0.8 ou < -0.8)
print("=== Paires de features très corrélées (|corr| > 0.8) ===")
corr_haute = []
for i in range(len(matrice_corr.columns)):
    for j in range(i+1, len(matrice_corr.columns)):
        val = matrice_corr.iloc[i, j]
        if abs(val) > 0.8:
            corr_haute.append({
                'Feature 1': matrice_corr.columns[i],
                'Feature 2': matrice_corr.columns[j],
                'Corrélation': round(val, 3)
            })

if corr_haute:
    display(pd.DataFrame(corr_haute).sort_values('Corrélation', ascending=False))
else:
    print("Aucune paire avec corrélation > 0.8")
# Out:
# === Paires de features très corrélées (|corr| > 0.8) ===
#                     Feature 1              Feature 2  Corrélation
# 1                   Frequency         UniqueInvoices        1.000
# 17      NegativeQuantityCount  CancelledTransactions        1.000
# 13             UniqueProducts     UniqueDescriptions        1.000
# 6                 MonetaryStd            MaxQuantity        0.973
# 4                 MonetaryStd            MonetaryMax        0.966
# 16  AvgProductsPerTransaction     AvgLinesPerInvoice        0.963
# 2               MonetaryTotal          TotalQuantity        0.922
# 11                MonetaryMax            MaxQuantity        0.921
# 8                 MonetaryMin            MinQuantity        0.919
# 15         UniqueDescriptions      TotalTransactions        0.880
# 14             UniqueProducts      TotalTransactions        0.878
# 0                     Recency                  Churn        0.859
# 10                MonetaryMax            MinQuantity       -0.916
# 9                 MonetaryMin            MaxQuantity       -0.916
# 12                MinQuantity            MaxQuantity       -0.961
# 3                 MonetaryStd            MonetaryMin       -0.967
# 5                 MonetaryStd            MinQuantity       -0.974
# 7                 MonetaryMin            MonetaryMax       -0.994

# %%
# ============================================================
# CELLULE 11 : Colonnes catégorielles
# ============================================================

colonnes_cat = df.select_dtypes(include='object').columns.tolist()
print(f"Colonnes catégorielles : {colonnes_cat}")

for col in colonnes_cat:
    print(f"\n=== {col} ===")
    print(df[col].value_counts())
# Out:
# Colonnes catégorielles : ['RegistrationDate', 'NewsletterSubscribed', 'LastLoginIP', 'RFMSegment', 'AgeCategory', 'SpendingCategory', 'CustomerType', 'FavoriteSeason', 'PreferredTimeOfDay', 'Region', 'LoyaltyLevel', 'ChurnRiskCategory', 'WeekendPreference', 'BasketSizeCategory', 'ProductDiversity', 'Gender', 'AccountStatus', 'Country']
#
# === RegistrationDate ===
# RegistrationDate
# 2010-12-21    11
# 12/10/2010    11
# 2010-12-22    10
# 01/01/2011    10
# 01/28/2011    10
#               ..
# 11/02/2011     1
# 11/22/2011     1
# 12/30/2011     1
# 2011-12-06     1
# 22/12/11       1
# Name: count, Length: 1700, dtype: int64
#
# === NewsletterSubscribed ===
# NewsletterSubscribed
# Yes    4372
# Name: count, dtype: int64
#
# === LastLoginIP ===
# LastLoginIP
# 59.252.219.201     1
# 77.255.247.14      1
# 51.139.78.80       1
# 10.212.80.124      1
# 186.34.121.80      1
#                   ..
# 28.217.44.198      1
# 190.170.94.224     1
# 22.250.38.14       1
# 226.235.111.122    1
# 154.168.54.141     1
# Name: count, Length: 4372, dtype: int64
#
# === RFMSegment ===
# RFMSegment
# Potentiels    1589
# Fidèles       1177
# Champions      979
# Dormants       627
# Name: count, dtype: int64
#
# === AgeCategory ===
# AgeCategory
# Inconnu    1311
# 65+         791
# 45-54       515
# 35-44       495
# 25-34       474
# 55-64       449
# 18-24       337
# Name: count, dtype: int64
#
# === SpendingCategory ===
# SpendingCategory
# High      1664
# Medium    1617
# VIP        876
# Low        215
# Name: count, dtype: int64
#
# === CustomerType ===
# CustomerType
# Occasionnel    1198
# Nouveau        1157
# Perdu           864
# Régulier        703
# Hyperactif      450
# Name: count, dtype: int64
#
# === FavoriteSeason ===
# FavoriteSeason
# Automne      1768
# Hiver         968
# Printemps     866
# Été           770
# Name: count, dtype: int64
#
# === PreferredTimeOfDay ===
# PreferredTimeOfDay
# Matin         1471
# Midi          1435
# Après-midi    1409
# Soir            57
# Name: count, dtype: int64
#
# === Region ===
# Region
# UK                     3959
# Europe continentale     284
# Europe du Nord           39
# Europe du Sud            27
# Europe centrale          16
# Moyen-Orient             10
# Océanie                   9
# Asie                      9
# Autre                     8
# Amérique du Nord          8
# Europe de l'Est           1
# Amérique du Sud           1
# Afrique                   1
# Name: count, dtype: int64
#
# === LoyaltyLevel ===
# LoyaltyLevel
# Nouveau    1714
# Établi     1588
# Jeune       970
# Ancien      100
# Name: count, dtype: int64
#
# === ChurnRiskCategory ===
# ChurnRiskCategory
# Faible      1695
# Critique    1454
# Moyen        743
# Élevé        480
# Name: count, dtype: int64
#
# === WeekendPreference ===
# WeekendPreference
# Inconnu    3125
# Semaine     774
# Weekend     473
# Name: count, dtype: int64
#
# === BasketSizeCategory ===
# BasketSizeCategory
# Moyen    2414
# Petit     982
# Grand     976
# Name: count, dtype: int64
#
# === ProductDiversity ===
# ProductDiversity
# Explorateur    3018
# Modéré         1071
# Spécialisé      283
# Name: count, dtype: int64
#
# === Gender ===
# Gender
# Unknown    1649
# F          1389
# M          1334
# Name: count, dtype: int64
#
# === AccountStatus ===
# AccountStatus
# Active       3944
# Suspended     213
# Pending       131
# Closed         84
# Name: count, dtype: int64
#
# === Country ===
# Country
# United Kingdom          3950
# Germany                   95
# France                    87
# Spain                     30
# Belgium                   24
# Switzerland               20
# Portugal                  19
# Italy                     15
# Finland                   12
# Norway                    10
# Australia                  9
# Netherlands                9
# Channel Islands            9
# Austria                    9
# Japan                      8
# Denmark                    8
# Sweden                     8
# Poland                     6
# Cyprus                     6
# Israel                     4
# Greece                     4
# Canada                     4
# Unspecified                4
# USA                        4
# EIRE                       3
# United Arab Emirates       2
# Bahrain                    2
# Malta                      2
# Lithuania                  1
# Iceland                    1
# Singapore                  1
# Lebanon                    1
# Saudi Arabia               1
# Czech Republic             1
# Brazil                     1
# European Community         1
# RSA                        1
# Name: count, dtype: int64
